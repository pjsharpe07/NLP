# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import nltk

# %%
one = "The best Monty Python sketch is the one about the dead parrot,  I laughed so hard."
two = "I laugh when I think about Python's Ministry of Silly Walks sketch, it is funny, funny, funny, the best!"
three ="Chocolate is the best ice cream dessert topping, with a great taste."
four = "The Lumberjack Song is the funniest Monty Python bit: I can't think of it without laughing."
five = "I would rather put strawberries on my ice cream for dessert, they have the best taste."
six = "The taste of caramel is a fantastic accompaniment to tasty mint ice cream."

combined = [one, two, three, four, five, six]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
vector = vectorizer.fit_transform(combined)

columns = vectorizer.get_feature_names()

X = pd.DataFrame(vector.toarray(), columns=columns)
y = ['comedy', 'comedy', 'ice_cream', 'comedy', 'ice_cream', 'ice_cream']

# %%
X
# Out:
#    accompaniment      best       bit  caramel  chocolate     cream      dead  \
# 0        0.00000  0.238719  0.000000  0.00000   0.000000  0.000000  0.402386
# 1        0.00000  0.152288  0.000000  0.00000   0.000000  0.000000  0.000000
# 2        0.00000  0.253839  0.000000  0.00000   0.427872  0.296221  0.000000
# 3        0.00000  0.000000  0.382804  0.00000   0.000000  0.000000  0.000000
# 4        0.00000  0.318834  0.000000  0.00000   0.000000  0.372067  0.000000
# 5        0.39412  0.000000  0.000000  0.39412   0.000000  0.272854  0.000000
#
#     dessert  fantastic  funniest  ...    python     silly    sketch      song  \
# 0  0.000000    0.00000  0.000000  ...  0.278577  0.000000  0.329962  0.000000
# 1  0.000000    0.00000  0.000000  ...  0.177714  0.256696  0.210495  0.000000
# 2  0.350861    0.00000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 3  0.000000    0.00000  0.382804  ...  0.265020  0.000000  0.000000  0.382804
# 4  0.440698    0.00000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5  0.000000    0.39412  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#    strawberries     taste    tasty     think   topping     walks
# 0      0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# 1      0.000000  0.000000  0.00000  0.210495  0.000000  0.256696
# 2      0.000000  0.296221  0.00000  0.000000  0.427872  0.000000
# 3      0.000000  0.000000  0.00000  0.313904  0.000000  0.000000
# 4      0.537427  0.372067  0.00000  0.000000  0.000000  0.000000
# 5      0.000000  0.272854  0.39412  0.000000  0.000000  0.000000
#
# [6 rows x 32 columns]

# %%
from sklearn.decomposition import PCA
from nltk.corpus import gutenberg
import re
from sklearn.model_selection import train_test_split

#reading in the data, this time in the form of paragraphs
emma=gutenberg.paras('austen-emma.txt')

emma_paras=[]
for paragraph in emma:
    para=paragraph[0]
    #removing the double-dash from all words
    para=[re.sub(r'--','',word) for word in para]
    #Forming each paragraph into a string and adding it to the list of strings.
    emma_paras.append(' '.join(para))

print(emma_paras[0:4])
# Out:
# ['[ Emma by Jane Austen 1816 ]', 'VOLUME I', 'CHAPTER I', 'Emma Woodhouse , handsome , clever , and rich , with a comfortable home and happy disposition , seemed to unite some of the best blessings of existence ; and had lived nearly twenty - one years in the world with very little to distress or vex her .']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test = train_test_split(emma_paras, test_size=0.4, random_state=0)

vectorizer = TfidfVectorizer(max_df=0.5, # drop words that occur in more than half the paragraphs
                             min_df=2, # only use words that appear at least twice
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf=vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])

#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)


#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[5])
print('Tf_idf vector:', tfidf_bypara[5])
# Out:
# Number of features: 1948
# Original sentence: A very few minutes more , however , completed the present trial .
# Tf_idf vector: {'minutes': 0.7127450310382584, 'present': 0.701423210857947}

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

#Our SVD data reducer.  We are going to reduce the feature space from 1379 to 130.
svd= TruncatedSVD(130)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 45.21366597234673
# Component 0:
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !"    0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# " Oh !     0.999289
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.634053
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.577296
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.565415
# " You are right , Mrs . Weston ," said Mr . Knightley warmly , " Miss Fairfax is as capable as any of us of forming a just opinion of Mrs . Elton .                         0.560957
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.528605
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.526145
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                                                 0.507951
# " Now ," said Emma , when they were fairly beyond the sweep gates , " now Mr . Weston , do let me know what has happened ."                                                 0.507405
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.507278
# " I do not admire it ," said Mr . Knightley .                                                                                                                               0.499669
# Name: 1, dtype: float64
# Component 2:
# CHAPTER I      0.998789
# CHAPTER X      0.998789
# CHAPTER I      0.998789
# CHAPTER V      0.998789
# CHAPTER X      0.998789
# CHAPTER V      0.998789
# CHAPTER V      0.998789
# CHAPTER X      0.998789
# CHAPTER I      0.998789
# CHAPTER XII    0.997848
# Name: 2, dtype: float64
# Component 3:
# " Ah !      0.992906
# " Ah !      0.992906
# " Ah !      0.992906
# " Ah !"     0.992906
# " Ah !      0.992906
# But ah !    0.992906
# " Ah !      0.992906
# " Ah !      0.992906
# " Ah !      0.992906
# " Ah !      0.992906
# Name: 3, dtype: float64
# Component 4:
# " There were misunderstandings between them , Emma ; he said so expressly .    0.650901
# Emma demurred .                                                                0.598701
# " Are you well , my Emma ?"                                                    0.598701
# Emma was silenced .                                                            0.587602
# At first it was downright dulness to Emma .                                    0.586485
# " Emma , my dear Emma "                                                        0.576918
# Emma could not resist .                                                        0.568320
# " It is not now worth a regret ," said Emma .                                  0.549068
# " For shame , Emma !                                                           0.541610
# " I am ready ," said Emma , " whenever I am wanted ."                          0.501266
# Name: 4, dtype: float64

# %% [markdown]
# __Test Set:__

# %%
X_test_lsa = lsa.fit_transform(X_test_tfidf)

variance_explained = svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_test_lsa, index=X_test)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 49.39215276176464
# Component 0:
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !"    0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# " Oh !     0.999921
# Name: 0, dtype: float64
# Component 1:
# " Well , Mrs . Weston ," said Emma triumphantly when he left them , " what do you say now to Mr . Knightley ' s marrying Jane Fairfax ?"                                                                                                                                                                                                                                                                                                             0.616192
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                                                                                                                                                                                                           0.599031
# Frank turned instantly to Emma , to claim her former promise ; and boasted himself an engaged man , which his father looked his most perfect approbation of  and it then appeared that Mrs . Weston was wanting _him_ to dance with Mrs . Elton himself , and that their business was to help to persuade him into it , which was done pretty soon . Mr . Weston and Mrs . Elton led the way , Mr . Frank Churchill and Miss Woodhouse followed .    0.568788
# " Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                               0.519138
# Mr . Weston was musing .                                                                                                                                                                                                                                                                                                                                                                                                                             0.505972
# While she was gone , Mr . Knightley called , and sat some time with Mr . Woodhouse and Emma , till Mr . Woodhouse , who had previously made up his mind to walk out , was persuaded by his daughter not to defer it , and was induced by the entreaties of both , though against the scruples of his own civility , to leave Mr . Knightley for that purpose .                                                                                       0.504032
# " Mrs . Weston ' s manners ," said Emma , " were always particularly good .                                                                                                                                                                                                                                                                                                                                                                          0.493442
# " I think , indeed ," said John Knightley pleasantly , " that Mr . Weston has some little claim .                                                                                                                                                                                                                                                                                                                                                    0.489488
# " Why , to be sure ," said Mr . Woodhouse " yes , certainly  I cannot deny that Mrs . Weston , poor Mrs . Weston , does come and see us pretty often  but then  she is always obliged to go away again ."                                                                                                                                                                                                                                            0.488777
# " It is Frank and Miss Fairfax ," said Mrs . Weston .                                                                                                                                                                                                                                                                                                                                                                                                0.485972
# Name: 1, dtype: float64
# Component 2:
# " Ah !     0.996961
# " Ah !"    0.996961
# " Ah !     0.996961
# " Ah !     0.996961
# " Ah !     0.996961
# " Ah !     0.996961
# " Ah !"    0.996961
# " Ah !     0.996961
# " Ah !     0.996961
# " Ah !     0.996961
# Name: 2, dtype: float64
# Component 3:
# " Mr .                                                                                                                                                                                                                                                                 0.633459
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                             0.563245
# Mr . Knightley was thoughtful again .                                                                                                                                                                                                                                  0.522974
# " You are not vain , Mr . Knightley .                                                                                                                                                                                                                                  0.506022
# Mr . Weston was musing .                                                                                                                                                                                                                                               0.500571
# Mr . Weston ' s own happiness was indisputable .                                                                                                                                                                                                                       0.452513
# She meant to be very happy , in spite of the scene being laid at Mr . Cole ' s ; and without being able to forget that among the failings of Mr . Elton , even in the days of his favour , none had disturbed her more than his propensity to dine with Mr . Cole .    0.423979
# " And I , Mr . Knightley , am equally stout in my confidence of its not doing them any harm .                                                                                                                                                                          0.422986
# Harriet , Mr . Elton , and Mr . Knightley , their own especial set , were the only persons invited to meet them ; the hours were to be early , as well as the numbers few ; Mr . Woodhouse ' s habits and inclination being consulted in every thing .                 0.399668
# " Christmas weather ," observed Mr . Elton .                                                                                                                                                                                                                           0.393634
# Name: 3, dtype: float64
# Component 4:
# " Yes , do ."                                                                   0.653348
# " Yes .                                                                         0.653348
# " Yes , sometimes he can ."                                                     0.653348
# " Yes I should , I am sure I should .                                           0.639324
# " Yes , so I imagined .                                                         0.607705
# " Yes  a good deal _nearer_ ."                                                  0.567853
# " Yes , our good Mrs . Elton .                                                  0.554262
# " Yes ; but we must not rest our claims on that distinction .                   0.546194
# " Yes , she would be , but that she thinks there will be another put - off .    0.544076
# " Yes , very soon .                                                             0.534204
# Name: 4, dtype: float64

# %% [markdown]
# ## Challenge 1:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test = train_test_split(emma_paras, test_size=0.4, random_state=0)

vectorizer = TfidfVectorizer(max_df=0.40, # drop words that occur in more than 40% the paragraphs
                             min_df=5, # only use words that appear at least five times
                             stop_words='english', 
                             lowercase=True, #convert everything to lower case (since Alice in Wonderland has the HABIT of CAPITALIZING WORDS for EMPHASIS)
                             use_idf=True,#we definitely want to use inverse document frequencies in our weighting
                             norm=u'l2', #Applies a correction factor so that longer paragraphs and shorter paragraphs get treated equally
                             smooth_idf=True #Adds 1 to all document frequencies, as if an extra document existed that used every word once.  Prevents divide-by-zero errors
                            )


#Applying the vectorizer
emma_paras_tfidf = vectorizer.fit_transform(emma_paras)
print("Number of features: %d" % emma_paras_tfidf.get_shape()[1])

#splitting into training and test sets
X_train_tfidf, X_test_tfidf= train_test_split(emma_paras_tfidf, test_size=0.4, random_state=0)


#Reshapes the vectorizer output into something people can read
X_train_tfidf_csr = X_train_tfidf.tocsr()

#number of paragraphs
n = X_train_tfidf_csr.shape[0]
#A list of dictionaries, one per paragraph
tfidf_bypara = [{} for _ in range(0,n)]
#List of features
terms = vectorizer.get_feature_names()
#for each paragraph, lists the feature words and their tf-idf scores
for i, j in zip(*X_train_tfidf_csr.nonzero()):
    tfidf_bypara[i][terms[j]] = X_train_tfidf_csr[i, j]

#Keep in mind that the log base 2 of 1 is 0, so a tf-idf score of 0 indicates that the word was present once in that sentence.
print('Original sentence:', X_train[5])
print('Tf_idf vector:', tfidf_bypara[5])
# Out:
# Number of features: 799
# Original sentence: A very few minutes more , however , completed the present trial .
# Tf_idf vector: {'minutes': 0.7127450310382584, 'present': 0.701423210857947}

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

#Our SVD data reducer.  We are going to reduce the feature space from 799 to 200 ~25%.
svd= TruncatedSVD(200)
lsa = make_pipeline(svd, Normalizer(copy=False))
# Run SVD on the training data, then project the training data.
X_train_lsa = lsa.fit_transform(X_train_tfidf)

variance_explained=svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_train_lsa,index=X_train)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 68.19661383854996
# Component 0:
# " Oh !     0.999042
# " Oh !"    0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# " Oh !     0.999042
# Name: 0, dtype: float64
# Component 1:
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                                                0.704725
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                                           0.611217
# " There were misunderstandings between them , Emma ; he said so expressly .                                                                                                 0.607211
# Emma found that it was not Mr . Weston ' s fault that the number of privy councillors was not yet larger .                                                                  0.573100
# " You get upon delicate subjects , Emma ," said Mrs . Weston smiling ; " remember that I am here . Mr .                                                                     0.565615
# " I do not know what your opinion may be , Mrs . Weston ," said Mr . Knightley , " of this great intimacy between Emma and Harriet Smith , but I think it a bad thing ."    0.532476
# " I do not admire it ," said Mr . Knightley .                                                                                                                               0.531571
# Emma was silenced .                                                                                                                                                         0.525343
# " Are you well , my Emma ?"                                                                                                                                                 0.525343
# At first it was downright dulness to Emma .                                                                                                                                 0.525343
# Name: 1, dtype: float64
# Component 2:
# CHAPTER I       1.0
# CHAPTER XIII    1.0
# CHAPTER III     1.0
# CHAPTER III     1.0
# CHAPTER XI      1.0
# CHAPTER VI      1.0
# CHAPTER V       1.0
# CHAPTER II      1.0
# CHAPTER VIII    1.0
# CHAPTER IX      1.0
# Name: 2, dtype: float64
# Component 3:
# " For shame , Emma !                                                           0.672194
# " Are you well , my Emma ?"                                                    0.672194
# Emma demurred .                                                                0.672194
# At first it was downright dulness to Emma .                                    0.672194
# Emma was silenced .                                                            0.672194
# Emma could not resist .                                                        0.672194
# " Emma , my dear Emma "                                                        0.600380
# " There were misunderstandings between them , Emma ; he said so expressly .    0.566224
# Emma was most sincerely interested .                                           0.554931
# " There might be scruples of delicacy , my dear Emma .                         0.459704
# Name: 3, dtype: float64
# Component 4:
# " Mr . Knightley was there too , was he ?"                                                                                                               0.584879
# Mr . Knightley might quarrel with her , but Emma could not quarrel with herself .                                                                        0.561049
# "` Mr .                                                                                                                                                  0.522669
# " I do not admire it ," said Mr . Knightley .                                                                                                            0.487224
# " You have made her too tall , Emma ," said Mr . Knightley .                                                                                             0.486676
# Mr . Knightley had done all in his power for Mr . Woodhouse ' s entertainment .                                                                          0.437339
# " In one respect , perhaps , Mr . Elton ' s manners are superior to Mr . Knightley ' s or Mr . Weston ' s .                                              0.435386
# Mr . Knightley grew angry .                                                                                                                              0.399041
# Mr . Woodhouse at last was off ; but Mr . Knightley , instead of being immediately off likewise , sat down again , seemingly inclined for more chat .    0.385096
# " Knightley !"                                                                                                                                           0.384022
# Name: 4, dtype: float64

# %% [markdown]
# __Test Set:__

# %%
X_test_lsa = lsa.fit_transform(X_test_tfidf)

variance_explained = svd.explained_variance_ratio_
total_variance = variance_explained.sum()
print("Percent variance captured by all components:",total_variance*100)

#Looking at what sorts of paragraphs our solution considers similar, for the first five identified topics
paras_by_component=pd.DataFrame(X_test_lsa, index=X_test)
for i in range(5):
    print('Component {}:'.format(i))
    print(paras_by_component.loc[:,i].sort_values(ascending=False)[0:10])
# Out:
# Percent variance captured by all components: 72.63294878904988
# Component 0:
# " Oh !         0.999869
# " Oh !         0.999869
# " Oh !         0.999869
# " Oh !"        0.999869
# " Me ! oh !    0.999869
# " Oh !         0.999869
# " Oh !         0.999869
# " Oh !         0.999869
# " Oh !         0.999869
# " Oh !         0.999869
# Name: 0, dtype: float64
# Component 1:
# " Well , Mrs . Weston ," said Emma triumphantly when he left them , " what do you say now to Mr . Knightley ' s marrying Jane Fairfax ?"                                                                                                                                                                                                                                                                                                             0.575834
# After tea , Mr . and Mrs . Weston , and Mr . Elton sat down with Mr . Woodhouse to cards .                                                                                                                                                                                                                                                                                                                                                           0.563421
# Nobody had any information to give ; and , after a few more wonderings , Emma said ,                                                                                                                                                                                                                                                                                                                                                                 0.520257
# Frank turned instantly to Emma , to claim her former promise ; and boasted himself an engaged man , which his father looked his most perfect approbation of  and it then appeared that Mrs . Weston was wanting _him_ to dance with Mrs . Elton himself , and that their business was to help to persuade him into it , which was done pretty soon . Mr . Weston and Mrs . Elton led the way , Mr . Frank Churchill and Miss Woodhouse followed .    0.507827
# " I think , indeed ," said John Knightley pleasantly , " that Mr . Weston has some little claim .                                                                                                                                                                                                                                                                                                                                                    0.506533
# " Mr .                                                                                                                                                                                                                                                                                                                                                                                                                                               0.488741
# While she was gone , Mr . Knightley called , and sat some time with Mr . Woodhouse and Emma , till Mr . Woodhouse , who had previously made up his mind to walk out , was persuaded by his daughter not to defer it , and was induced by the entreaties of both , though against the scruples of his own civility , to leave Mr . Knightley for that purpose .                                                                                       0.476430
# Mr . Weston was musing .                                                                                                                                                                                                                                                                                                                                                                                                                             0.472230
# " Why , to be sure ," said Mr . Woodhouse " yes , certainly  I cannot deny that Mrs . Weston , poor Mrs . Weston , does come and see us pretty often  but then  she is always obliged to go away again ."                                                                                                                                                                                                                                            0.452082
# " Mrs . Weston ' s manners ," said Emma , " were always particularly good .                                                                                                                                                                                                                                                                                                                                                                          0.451844
# Name: 1, dtype: float64
# Component 2:
# CHAPTER XIV      1.0
# CHAPTER IV       1.0
# CHAPTER XVIII    1.0
# CHAPTER XV       1.0
# CHAPTER XII      1.0
# CHAPTER XVII     1.0
# CHAPTER XI       1.0
# CHAPTER VIII     1.0
# CHAPTER VII      1.0
# CHAPTER XVIII    1.0
# Name: 2, dtype: float64
# Component 3:
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !"    0.995976
# " Ah !     0.995976
# " Ah !     0.995976
# " Ah !"    0.995976
# Name: 3, dtype: float64
# Component 4:
# " And I do envy him , Emma .                                                                                                                        0.710229
# " Emma !"                                                                                                                                           0.710229
# Emma had done .                                                                                                                                     0.710229
# Emma wondered on what , of all the medley , she would fix .                                                                                         0.710229
# " My Emma !"                                                                                                                                        0.710229
# Nobody had any information to give ; and , after a few more wonderings , Emma said ,                                                                0.592588
# " No , no ," said Emma , " it will not reckon low .                                                                                                 0.474964
# " Such an imagination has crossed me , I own , Emma ; and if it never occurred to you before , you may as well take it into consideration now ."    0.422101
# " Take it ," said Emma , smiling , and pushing the paper towards Harriet " it is for you .                                                          0.421387
# " He has not been here yet ," replied Emma .                                                                                                        0.411047
# Name: 4, dtype: float64

# %%
# Compute document similarity using LSA components
similarity = np.asarray(np.asmatrix(X_test_lsa) * np.asmatrix(X_test_lsa).T)
#Only taking the first 10 sentences
sim_matrix=pd.DataFrame(similarity,index=X_test).iloc[0:10,0:10]
#Making a plot
ax = sns.heatmap(sim_matrix, yticklabels=range(10))
plt.show()

#Generating a key for the plot.
print('Key:')
for i in range(10):
    print(i,sim_matrix.index[i])
# Out:
# Key:
# 0 Mr . Woodhouse had so completely made up his mind to the visit , that in spite of the increasing coldness , he seemed to have no idea of shrinking from it , and set forward at last most punctually with his eldest daughter in his own carriage , with less apparent consciousness of the weather than either of the others ; too full of the wonder of his own going , and the pleasure it was to afford at Randalls to see that it was cold , and too well wrapt up to feel it .
# 1 " Oh !
# 2 " Oh no , no !
# 3 Such was Jane Fairfax ' s history .
# 4 " That has been a good deal the case , my dear ; but not to the degree you mention .
# 5 " And I am quite serious too , I assure you ," replied Mrs . Elton gaily , " in resolving to be always on the watch , and employing my friends to watch also , that nothing really unexceptionable may pass us ."
# 6 " And here is Mrs . Weston and Mr . Frank Churchill too ! Quite delightful ; so many friends !"
# 7 " You may well class the delight , the honour , and the comfort of such a situation together ," said Jane , " they are pretty sure to be equal ; however , I am very serious in not wishing any thing to be attempted at present for me .
# 8 Harriet , Mr . Elton , and Mr . Knightley , their own especial set , were the only persons invited to meet them ; the hours were to be early , as well as the numbers few ; Mr . Woodhouse ' s habits and inclination being consulted in every thing .
# 9 " Oh !
